# %%
import pandas as pd 
import spacy
import bs4 
from bs4 import BeautifulSoup 
import urllib.request as urllib_request
from urllib.request import urlopen
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_predict
from sklearn import metrics
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import pickle
import time

# %%
#Conexao com a base de dados
from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')
db = client.sprint3
materia_no_banco = db.materia

# %%
#Funcao para gerar a word cloud
def wordcloud_artigo(artigo):
    todas_palavras = ' '.join([texto for texto in artigo.texto_completo])
    nuvem_palvras = WordCloud(width= 500, height= 300, max_font_size = 110, collocations = False).generate(todas_palavras)
    plt.figure(figsize=(10,7))
    plt.imshow(nuvem_palvras, interpolation='bilinear')
    plt.title(f'{artigo.titulo[0]}')
    plt.axis("off")
    plt.show()  

#funcao para tirar espacos e caracteres nao alfabeticos
def trata_textos(doc):
    tokens_validos = []
    for token in doc:
        e_valido = not token.is_stop and token.is_alpha
        if e_valido:
            tokens_validos.append(token.text)    
    if len(tokens_validos) > 2:
        return " ".join(tokens_validos)

# %%
arquivo = open('link_das_materias.txt','r')
#Iterando cada link do arquivo para retirar os dados das materias
for link in arquivo:
    #Pegando o conteudo
    url = link
    response = urlopen(url)
    html = response.read()
    html = html.decode('utf-8')
        
    #Usando o BeautifulSoup para trabalhar com o conteudo
    soup = BeautifulSoup(html, 'html.parser')

    #Pegando titulo da materia
    titulo_materia = soup.find('h1', {"class": "c-content-head__title"}).get_text()
    titulo_materia = " ".join(titulo_materia.split())

    #Pegando os paragrafos da materia
    materia = soup.find('div', {'class': "c-news__body"}).findAll('p')
    paragrafos = []
    for paragrafo in materia:
        paragrafos.append(paragrafo.get_text())
    texto_completo = ' '.join(paragrafos)
        
    #Texto em minusculo
    paragrafos_minusculo = []
    for texto in paragrafos:
        texto = texto.lower()
        paragrafos_minusculo.append(texto)

    #Verificando se há as materias no banco e as inserindo se nao houver
    materia_para_o_banco = {
        'Titulo': titulo_materia,
        'Conteudo': paragrafos_minusculo
    }  

    #Reconhecendo no banco de dados
    materia_no_banco = db.Materias
    if not materia_no_banco.find_one({'Titulo': titulo_materia}):       
        insere = materia_no_banco.insert_one(materia_para_o_banco)
        print(f'Inserindo a materia: -| {titulo_materia}')
    else:
        print(f'Essa matéria já existe no Banco: -| {titulo_materia}')

    #Transformando o artigo em um data frame do pandas pra usar o spacy
    df_artigo = pd.DataFrame(index=[0] ,data={'titulo':titulo_materia, 'texto_completo': texto_completo})
    pd.set_option('display.max_colwidth', None)

    #usando spacy
    nlp = spacy.load('pt_core_news_sm')
    doc = nlp(str(df_artigo))

    #Lista NER
    entidades_nomeadas = nlp(str(df_artigo['texto_completo']))
    lista_de_entidades = []
    for token in entidades_nomeadas.ents:
        if token.orth_ not in lista_de_entidades and not token.orth_ == 'Name':
            lista_de_entidades.append(token.orth_)
        
    #tratando dados
    textos_normalizados = [trata_textos(doc) for doc in nlp.pipe(df_artigo['texto_completo'], batch_size= 500, n_process=-1)]

    #Verbos no artigo
    verbos_artigo = []
    for token in entidades_nomeadas:
        if token.pos_ == 'VERB' and token.is_alpha == True and token.orth_:
            verbos_artigo.append(token.orth_)

    #Prints
    print(f'Aqui estão os verbos utilizados nessa matéria: {verbos_artigo}')
    print(f'Aqui estão as entidades nomeadas dessa matéria: {lista_de_entidades}')
    print('------------------------------------------------')
    ########

    #Plotando a Word Cloud
    artigo = pd.DataFrame({
        'titulo': titulo_materia,
        'texto_completo': textos_normalizados
    },index=[0])    
    wordcloud_artigo(artigo)
arquivo.close()
# Out:
# Essa matéria já existe no Banco: -| 1971: Ofensiva de guerrilheiros no Camboja deixa 200 mortos
# Aqui estão os verbos utilizados nessa matéria: ['conseguiram', 'destruir', 'estendeu', 'matou', 'destruiu', 'aumentou']
# Aqui estão as entidades nomeadas dessa matéria: ['Guerrilheiros', 'Phnom Penh', 'Camboja', 'Indochina']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1971: Embaixador diz que, durante seu sequestro, lia notícias da negociação
# Aqui estão os verbos utilizados nessa matéria: ['afirmou', 'acompanhava', 'raptado', 'aceitou', 'libertar', 'disse', 'sentiu', 'isolado', 'receber', 'pude', 'acompanhar', 'vigiavam', 'mascarados']
# Aqui estão as entidades nomeadas dessa matéria: ['Suíça', 'Brasil', 'Giovanni Enrico Bucher', 'Chile', 'Bucher']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1971: Lista de presos que serão trocados por embaixador está completa
# Aqui estão os verbos utilizados nessa matéria: ['informou', 'recebeu', 'libertados', 'sequestrado', 'disseram', 'recebeu', 'assinada', 'citaram', 'informou', 'decidir', 'enviados', 'realizado']
# Aqui estão as entidades nomeadas dessa matéria: ['Suíça', 'Brasil', 'Giovanni Enrico Bucher', 'Rio de Janeiro.\\r\\nEm', 'Justiça', 'Alfredo Buzaid', 'Relações Exteriores', 'Mário Gibson Barboza']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1970: Grande incêndio destrói ala da Volkswagen em São Bernardo
# Aqui estão os verbos utilizados nessa matéria: ['irrompeu', 'funcionavam', 'atingida', 'acabou', 'ruindo', 'começou', 'trabalhavam', 'chegou', 'publicar', 'morrido', 'informou', 'durou', 'contido']
# Aqui estão as entidades nomeadas dessa matéria: ['Volkswagen', 'São Bernardo do Campo', 'via Anchieta', 'Folha']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1970: Embaixador da Suíça no Brasil é sequestrado no Rio de Janeiro
# Aqui estão os verbos utilizados nessa matéria: ['sequestrado', 'fazia', 'baleado', 'realizar', 'bloquearam', 'saltou', 'baleado', 'provocou', 'Levando', 'fugiu']
# Aqui estão as entidades nomeadas dessa matéria: ['Suíça', 'Brasil', 'Giovanni Enrico Bucher', 'Rio de Janeiro', 'Hélio Carvalho de Araújo', 'Conde de Baependi', 'Laranjeiras']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1921: Serviço Sanitário não fala em caso fatal de meningite em boletins
# Aqui estão os verbos utilizados nessa matéria: ['há', 'tiveram', 'veio', 'morreram', 'informam', 'mataram', 'Relatam', 'definidas', 'incluídos', 'silencia', 'citados']
# Aqui estão as entidades nomeadas dessa matéria: ['São Paulo', 'Demógrafo-Sanitária', 'Caçapava', 'SP', 'S. Bento', 'Hospital do Isolamento', 'Relatam', 'Serviço Sanitário']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1921: Com matança de gado em São Paulo, risco de escassez de leite preocupa
# Aqui estão os verbos utilizados nessa matéria: ['matar', 'urge', 'realizado', 'tomado', 'informou', 'existe', 'faltar', 'parece', 'há', 'teria', 'vinda', 'agrada']
# Aqui estão as entidades nomeadas dessa matéria: ['São Paulo', 'Barretos']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1921: Governo pretende iniciar a cobrança do imposto sobre jogos em cassinos
# Aqui estão os verbos utilizados nessa matéria: ['efetuar', 'indicou', 'fez', 'encarregada', 'regulamentar', 'terá', 'coletada', 'disse', 'tratou', 'aprovado', 'alterada', 'baixado']
# Aqui estão as entidades nomeadas dessa matéria: ['Recebedoria Severiano Cavalcanti', 'A Noite', 'Rio', 'Cavalcanti', 'Ministério da Fazenda']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1921: Aviador Orton Hoover bate recorde ao fazer travessia SP-RJ em 2h15
# Aqui estão os verbos utilizados nessa matéria: ['conseguiu', 'registrar', 'cobriu', 'registrado', 'levantou', 'dirige', 'Aterrissou', 'mudou', 'viajar']
# Aqui estão as entidades nomeadas dessa matéria: ['Orton Hoover', 'Brasil', 'São Paulo', 'Rio de Janeiro', 'Hoover', 'Campo de Indianópolis', 'Campo dos Afonsos', 'Rio']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1921: Preços do feijão e de outros alimentos sobem durante peste bovina
# Aqui estão os verbos utilizados nessa matéria: ['fala', 'elevaram', 'têm', 'assistido', 'cruzados', 'for', 'fiscalizado', 'verá', 'elevou', 'sabe', 'Dizem']
# Aqui estão as entidades nomeadas dessa matéria: ['São Paulo', 'Municipal', 'Prefeitura']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1968: Governo federal baixa AI-5 e decreta fechamento do Congresso Nacional
# Aqui estão os verbos utilizados nessa matéria: ['anunciou', 'divulgado', 'determina', 'definida', 'ocorre', 'conceder']
# Aqui estão as entidades nomeadas dessa matéria: ['ministro da Justiça', 'Luís Antônio da Gama e Silva', 'Ato Institucional nº 5', 'AI-5', 'Ato Complementar', 'Institucional', 'Congresso Nacional', 'Arthur da Costa e Silva', 'Exército', 'Marinha', 'Aeronáutica', 'Gama e Silva', 'Palácio das Laranjeiras', 'Rio', 'Câmara', 'Márcio Moreira Alves', 'MDB']
# ------------------------------------------------
# Essa matéria já existe no Banco: -| 1971: Dom Paulo Evaristo Arns sofre acidente automobilístico em SC
# Aqui estão os verbos utilizados nessa matéria: ['teve', 'exposta', 'sofrer', 'dirigido', 'capotou', 'tentar', 'desviar', 'iam', 'assistir']
# Aqui estão as entidades nomeadas dessa matéria: ['arcebispo de São Paulo', 'dom Paulo', 'Evaristo Arns', 'Santa Catarina', 'Antonio Poeing', 'BR-101', 'Helena', 'Zilda', 'Ida', 'Forquilhinha']
# ------------------------------------------------

# %%
#Pegando os dados do csv e os separando em duas colunas
dataset = pd.read_csv('Tweets_Mg.csv')
classes = dataset['Classificacao'].values
tweets_bruto  = dataset["Text"].values

#texto para minusculo
textos = []
for texto in tweets_bruto:
    texto = texto.lower()
    textos.append(texto)

#tratando dados
textos_normalizados = [trata_textos(doc) for doc in nlp.pipe(textos, batch_size= 500, n_process=-1)]

#inserindo no dataset
dataset.insert(1,"texto_tratado",textos_normalizados)
dataset = dataset.drop_duplicates(subset='texto_tratado', keep='first')

# %%
#Definindo dataset separado
df_tweets = dataset[['texto_tratado','Classificacao']]

#tirando linhas duplicadas
df_tweets = df_tweets.drop_duplicates(subset='texto_tratado', keep='first')

#tirando linhas none
df_tweets = df_tweets.dropna()

# %%
#Criando nlp
nlp = spacy.load('pt_core_news_sm')
doc = nlp(str(df_tweets))

# %%
#Construindo o modelo
textos_modelo = df_tweets['texto_tratado'].values
classes_modelo = df_tweets['Classificacao'].values

vectorizer = CountVectorizer(analyzer = "word")
freq_tweets = vectorizer.fit_transform(textos_modelo[:2700])

SEED = 22
np.random.seed(SEED)
modelo = MultinomialNB()
modelo.fit(freq_tweets, classes_modelo[:2700])
# Out:
# MultinomialNB()

# %%
testes = textos_modelo[2700:]

freq_testes = vectorizer.transform(testes)
modelo.predict(freq_testes)
# Out:
# array(['Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Negativo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Neutro', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Neutro',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Neutro', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Neutro', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Neutro', 'Neutro', 'Neutro', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Neutro', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Neutro', 'Neutro', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Neutro', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Neutro',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Neutro', 'Positivo', 'Positivo', 'Positivo', 'Neutro', 'Neutro',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Neutro',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Neutro', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Neutro', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Neutro', 'Neutro', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Neutro', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Neutro', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Neutro', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Neutro', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Neutro', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo',
#        'Positivo', 'Positivo', 'Positivo', 'Positivo', 'Positivo'],
#       dtype='<U8')

# %%
#Avaliando o modelo
resultados = cross_val_predict(modelo, freq_tweets, classes_modelo, cv = 10)

# acuracia
acuracia = metrics.accuracy_score(classes_modelo, resultados)
print(f'A acuracia foi de: {acuracia:.02f}% \n')

#medidas de avaliacao
print(metrics.classification_report(classes_modelo, resultados, labels=['Positivo', 'Negativo', 'Neutro']))
# Out:
# A acuracia foi de: 0.82%
#
#               precision    recall  f1-score   support
#
#     Positivo       0.90      0.84      0.87      1422
#     Negativo       0.65      0.89      0.75       556
#       Neutro       0.85      0.78      0.81      1441
#
#     accuracy                           0.82      3419
#    macro avg       0.80      0.84      0.81      3419
# weighted avg       0.84      0.82      0.83      3419

# %%
arquivo = open('link_das_materias.txt','r')
for link in arquivo:
    #conexão com o link
    url = link
    response = urlopen(url)
    html = response.read()
    html = html.decode('utf-8')
        
    #Usando o BeautifulSoup para trabalhar com o conteudo
    soup = BeautifulSoup(html, 'html.parser')

    #pegando titulo da materia
    titulo_materia = soup.find('h1', {"class": "c-content-head__title"}).get_text() 

    #Pegando os paragrafos da materia
    materia = soup.find('div', {'class': "c-news__body"}).findAll('p')

    print(f'E assim foram classificados os paragrafos da matéria: {titulo_materia}')
    for paragrafo in materia:
        freq_testes = vectorizer.transform([paragrafo.get_text()])
        previsao = modelo.predict(freq_testes)
        print(f'O paragrafo: {paragrafo.get_text()} -- Foi considerado: {previsao[0]}')
    print('--------------------------------------------------------------------------')
arquivo.close()
# Out:
# E assim foram classificados os paragrafos da matéria:
#     1971: Ofensiva de guerrilheiros no Camboja deixa 200 mortos
#
# O paragrafo: Guerrilheiros cambojanos, vietcongues e norte-vietnamitas conseguiram destruir na madrugada desta sexta-feira (22) grande parte das instalações do aeroporto internacional de Phnom Penh, capital do Camboja. -- Foi considerado: Neutro
# O paragrafo: Esse foi o primeiro ataque contra a cidade desde que a guerra na Indochina se estendeu ao Camboja, em março de 1970. A ação matou cerca de 200 pessoas, entre militares e civis.  -- Foi considerado: Positivo
# O paragrafo: O fogo dos morteiros destruiu dois depósitos de munição, três hangares e vários aviões e helicópteros. Depois do bombardeio, um comando suicida com 18 homens aumentou a destruição. -- Foi considerado: Negativo
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1971: Embaixador diz que, durante seu sequestro, lia notícias da negociação
#
# O paragrafo: O embaixador da Suíça no Brasil, Giovanni Enrico Bucher, afirmou que acompanhava no cativeiro as notícias sobre a negociação para o fim do seu sequestro. -- Foi considerado: Neutro
# O paragrafo: Ele foi raptado no dia 7 de dezembro e solto na manhã deste sábado (16). O governo brasileiro aceitou libertar 70 presos, que foram para o Chile, em troca da sua liberdade.  -- Foi considerado: Neutro
# O paragrafo: Bucher disse que, nos primeiros dias do sequestro, ele se sentiu totalmente isolado, sem receber nenhum jornal. -- Foi considerado: Neutro
# O paragrafo: "Em seguida, pude acompanhar pela imprensa o andamento das negociações. Fiz perguntas aos que me vigiavam, sempre mascarados de grandes capuzes." -- Foi considerado: Negativo
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1971: Lista de presos que serão trocados por embaixador está completa
#
# O paragrafo: O governo informou que recebeu a lista completa de presos que serão libertados em troca do fim do sequestro do embaixador da Suíça no Brasil, Giovanni Enrico Bucher. -- Foi considerado: Positivo
# O paragrafo: O diplomata foi sequestrado em 7 de dezembro de 1970, no Rio de Janeiro.
# Em nota oficial, os ministros da Justiça, Alfredo Buzaid, e das Relações Exteriores, Mário Gibson Barboza, disseram que o governo recebeu a lista assinada pelo embaixador da Suíça. Eles não citaram os nomes nem o número de presos. -- Foi considerado: Neutro
# O paragrafo: O governo apenas informou que ainda irá decidir para qual país os libertados serão enviados e também quando será realizado o embarque. -- Foi considerado: Negativo
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1970: Grande incêndio destrói ala da Volkswagen em São Bernardo
#
# O paragrafo: Um grande incêndio irrompeu nas instalações industriais da Volkswagen, em São Bernardo do Campo, no quilômetro 23 da via Anchieta, por volta das 8h desta sexta-feira (18). -- Foi considerado: Positivo
# O paragrafo: A ala 13, onde funcionavam três linhas de montagem, foi atingida e acabou ruindo. -- Foi considerado: Negativo
# O paragrafo: Quando o fogo começou, 4.000 operários trabalhavam nessa ala (a Folha chegou a publicar que 30 pessoas teriam morrido, mas a Volkswagen informou posteriormente que o número correto era de uma morte, dois feridos graves e várias pessoas com ferimentos leves). -- Foi considerado: Positivo
# O paragrafo: O incêndio na Volkswagen durou mais de 12 horas para ser contido. -- Foi considerado: Positivo
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1970: Embaixador da Suíça no Brasil é sequestrado no Rio de Janeiro
#
# O paragrafo: O embaixador da Suíça no Brasil, Giovanni Enrico Bucher, foi sequestrado na manhã desta segunda-feira (7) no Rio de Janeiro. Durante a ação, o agente de polícia federal Hélio Carvalho de Araújo, que fazia a segurança do diplomata, foi baleado e está internado em estado grave. -- Foi considerado: Positivo
# O paragrafo: Para realizar o rapto, os sequestradores bloquearam o automóvel do embaixador em meio ao intenso trânsito da rua Conde de Baependi, nas Laranjeiras. Nesse momento, o agente saltou do carro sendo baleado na região da nuca. Segundo os médicos, o tiro provocou uma lesão medular. -- Foi considerado: Neutro
# O paragrafo: Levando o diplomata, o grupo fugiu em dois veículos. -- Foi considerado: Positivo
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1921: Serviço Sanitário não fala em caso fatal de meningite em boletins
#
# O paragrafo: Não há referência a casos fatais de meningite em São Paulo nos dois últimos boletins da repartição Demógrafo-Sanitária, que são referentes ao período de 9 a 23 de maio. -- Foi considerado: Neutro
# O paragrafo: Porém, dois episódios na cidade tiveram larga divulgação pela imprensa: o do soldado que veio de Caçapava (SP) e o de um aluno do ginásio do S. Bento. Os dois morreram no Hospital do Isolamento. -- Foi considerado: Positivo
# O paragrafo: Os boletins informam as doenças que mataram centenas de pessoas. Relatam também moléstias mal definidas. É possível que registros de meningite estejam lá incluídos. Assim, o Serviço Sanitário silencia, ao menos, sobre os casos citados pela imprensa. -- Foi considerado: Neutro
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1921: Com matança de gado em São Paulo, risco de escassez de leite preocupa
#
# O paragrafo: Com a decisão das autoridades de matar todo o gado que está na cidade de São Paulo por causa da peste bovina, urge a questão de como será realizado o abastecimento de leite aos paulistanos. -- Foi considerado: Positivo
# O paragrafo: É possível que a prefeitura tenha tomado providências, mas não informou se existe o risco de faltar leite aos moradores durante o período da matança das vacas. -- Foi considerado: Negativo
# O paragrafo: Já sobre o consumo de carne, segundo declarações da autoridade municipal, parece que não há possibilidade de falta. Pelo contrário, teria até em abundância, com a carne vinda de Barretos, mas que não agrada a muitos paulistanos. -- Foi considerado: Positivo
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1921: Governo pretende iniciar a cobrança do imposto sobre jogos em cassinos
#
# O paragrafo: O governo vai efetuar a cobrança do imposto sobre as quantias em giro nas bancas dos cassinos nas estações balneárias. Foi isso o que indicou o funcionário da Recebedoria Severiano Cavalcanti (que fez parte da comissão encarregada de regulamentar esse tributo) ao jornal A Noite, do Rio. -- Foi considerado: Neutro
# O paragrafo: “É uma fonte de receita com aplicação especial aos serviços de saúde pública e forçosamente terá de ser coletada essa renda”, disse Cavalcanti. -- Foi considerado: Neutro
# O paragrafo: O Ministério da Fazenda tratou da regulamentação do imposto (aprovado em 1920), depois de alterada a taxa de 15% para 2%. -- Foi considerado: Positivo
# O paragrafo: Até agora, porém, o regulamento não foi baixado. -- Foi considerado: Neutro
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1921: Aviador Orton Hoover bate recorde ao fazer travessia SP-RJ em 2h15
#
# O paragrafo: O arrojado aviador americano Orton Hoover conseguiu de maneira brilhante registrar um dos feitos mais admiráveis da aviação no Brasil nesta quarta-feira (11). -- Foi considerado: Neutro
# O paragrafo: Ele cobriu a distância entre São Paulo e Rio de Janeiro em duas horas e 15 minutos, o menor tempo já registrado. -- Foi considerado: Neutro
# O paragrafo: Hoover levantou voo às 9h45 no Campo de Indianópolis, onde está instalada a escola de aviação civil que ele mesmo dirige. -- Foi considerado: Positivo
# O paragrafo: Aterrissou no Campo dos Afonsos, no Rio, às 12h. -- Foi considerado: Positivo
# O paragrafo: A intenção do piloto era voar de volta para São Paulo durante a tarde, mas mudou os planos para viajar nesta quinta-feira (12). -- Foi considerado: Neutro
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1921: Preços do feijão e de outros alimentos sobem durante peste bovina
#
# O paragrafo: Em um período em que tanto se fala da peste bovina, os preços de gêneros de primeira necessidade se elevaram muito em São Paulo. -- Foi considerado: Neutro
# O paragrafo: Só que alguns dos alimentos não têm relação direta com a questão da peste. -- Foi considerado: Neutro
# O paragrafo: As autoridades têm assistido ao aumento absurdo de braços cruzados. -- Foi considerado: Negativo
# O paragrafo: Quem for a um mercado (mesmo o Municipal que é fiscalizado diretamente pelos agentes da Prefeitura) verá que nem a guerra elevou tanto o preço do feijão, da batata, do arroz e de vários outros gêneros de consumo. -- Foi considerado: Neutro
# O paragrafo: Por quê? Qual o motivo? Ninguém sabe. Dizem apenas: a peste bovina. -- Foi considerado: Negativo
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1968: Governo federal baixa AI-5 e decreta fechamento do Congresso Nacional
#
# O paragrafo: O ministro da Justiça, Luís Antônio da Gama e Silva, anunciou nesta sexta-feira (13), por volta das 23h, o Ato Institucional nº 5 (AI-5), que já está em vigor. -- Foi considerado: Neutro
# O paragrafo: Também foi divulgado o Ato Complementar, decorrente do Institucional, que determina o recesso do Congresso Nacional sem prazo definido. -- Foi considerado: Neutro
# O paragrafo: A instauração do AI-5 foi definida após reunião do presidente Arthur da Costa e Silva com os ministros de Exército, Marinha e Aeronáutica, além de Gama e Silva, no Palácio das Laranjeiras, no Rio. -- Foi considerado: Neutro
# O paragrafo: A ação do governo ocorre depois da negativa da Câmara em conceder a licença para a cassação do deputado Márcio Moreira Alves, do MDB. -- Foi considerado: Neutro
# --------------------------------------------------------------------------
# E assim foram classificados os paragrafos da matéria:
#     1971: Dom Paulo Evaristo Arns sofre acidente automobilístico em SC
#
# O paragrafo: O arcebispo de São Paulo, dom Paulo Evaristo Arns, teve fratura exposta no tornozelo e escoriações na cabeça, ao sofrer um acidente automobilístico, em Santa Catarina, nesta sexta-feira (14). Segundo os médicos, seu estado de saúde é bom. -- Foi considerado: Neutro
# O paragrafo: O carro, que era dirigido pelo irmão marista Antonio Poeing, capotou na rodovia BR-101 após tentar desviar de uma pedra na pista. -- Foi considerado: Neutro
# O paragrafo: A mãe de dom Paulo, Helena, e as irmãs dele Zilda e Ida também estavam no automóvel. -- Foi considerado: Neutro
# O paragrafo: Eles iam para Forquilhinha, terra natal do arcebispo, para assistir a uma cerimônia religiosa. -- Foi considerado: Positivo
# --------------------------------------------------------------------------

# %%
dados_treino = df_tweets.to_dict('list')
valor_treino = ((dados_treino))

# %%
##Salvando o modelo no banco de dados
pickled_model = pickle.dumps(modelo)

#dados
dados_treino = df_tweets[:2700].to_dict('list')
valor_treino = ([dados_treino])
dados_teste = df_tweets[:2700].to_dict('list')
valor_teste = ([dados_teste])

#Conexao
client = MongoClient('mongodb://localhost:27017/')

#Banco
db = client.sprint3

#Colecao
modelo_no_banco = db['Modelo']

info = modelo_no_banco.insert_one({'MultinomialNB': pickled_model, 'dados_treino': dados_treino , 'dados_teste': dados_teste, 'created_time':time.time()})
print(info.inserted_id, 'Foi salvo com esse ID no banco!')
    
details = {
    'inserted_id':info.inserted_id,
    'MultinomialNB': pickled_model,
    'dados_treino':dados_treino,
    'dados_teste': dados_teste,
    'created_time':time.time()
}
print(details)
# Out:
# 60bd8bbb18d4a8b9ea40bdc5 Foi salvo com esse ID no banco!
# {'inserted_id': ObjectId('60bd8bbb18d4a8b9ea40bdc5'), 'MultinomialNB': b'\x80\x04\x95\xff\x01\x00\x00\x00\x00\x00\x00\x8c\x13sklearn.naive_bayes\x94\x8c\rMultinomialNB\x94\x93\x94)\x81\x94}\x94(\x8c\x05alpha\x94G?\xf0\x00\x00\x00\x00\x00\x00\x8c\tfit_prior\x94\x88\x8c\x0bclass_prior\x94N\x8c\x0en_features_in_\x94M9\x15\x8c\x0bn_features_\x94M9\x15\x8c\x08classes_\x94\x8c\x15numpy.core.multiarray\x94\x8c\x0c_reconstruct\x94\x93\x94\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94K\x00\x85\x94C\x01b\x94\x87\x94R\x94(K\x01K\x03\x85\x94h\x0e\x8c\x05dtype\x94\x93\x94\x8c\x02U8\x94\x89\x88\x87\x94R\x94(K\x03\x8c\x01<\x94NNNK K\x04K\x08t\x94b\x89C`N\x00\x00\x00e\x00\x00\x00g\x00\x00\x00a\x00\x00\x00t\x00\x00\x00i\x00\x00\x00v\x00\x00\x00o\x00\x00\x00N\x00\x00\x00e\x00\x00\x00u\x00\x00\x00t\x00\x00\x00r\x00\x00\x00o\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00P\x00\x00\x00o\x00\x00\x00s\x00\x00\x00i\x00\x00\x00t\x00\x00\x00i\x00\x00\x00v\x00\x00\x00o\x00\x00\x00\x94t\x94b\x8c\x0cclass_count_\x94h\rh\x10K\x00\x85\x94h\x12\x87\x94R\x94(K\x01K\x03\x85\x94h\x17\x8c\x02f8\x94\x89\x88\x87\x94R\x94(K\x03h\x1bNNNJ\xff\xff\xff\xffJ\xff\xff\xff\xffK\x00t\x94b\x89C\x18\x00\x00\x00\x00\x00`\x81@\x00\x00\x00\x00\x00\x84\x96@\x00\x00\x00\x00\x00\xf8\x85@\x94t\x94b\x8c\x0efeature_count_\x94h\rh\x10K\x00\x85\x94h\x12\x87\x94R\x94(K\x01K\x03M9\x15\x86\x94h&\x89BX@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x18@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x08@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x08@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x08@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf0?\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x08@\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0 ...
